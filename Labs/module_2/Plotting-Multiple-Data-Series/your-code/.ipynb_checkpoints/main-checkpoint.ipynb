# %% [markdown]
# # Plotting Multiple Data Series
#
# Complete the following set of exercises to solidify your knowledge of plotting multiple data series with pandas, matplotlib, and seaborn. Part of the challenge that comes with plotting multiple data series is transforming the data into the form needed to visualize it like you want. For some of the exercises in this lab, you will need to transform the data into the form most appropriate for generating the visualization and then create the plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('../data/liquor_store_sales.csv')
data.head()
# Out:
#    Year  Month                      Supplier ItemCode  \
# 0  2017      4               ROYAL WINE CORP   100200
# 1  2017      4      SANTA MARGHERITA USA INC   100749
# 2  2017      4            JIM BEAM BRANDS CO    10103
# 3  2017      4  HEAVEN HILL DISTILLERIES INC    10120
# 4  2017      4               ROYAL WINE CORP   101664
#
#                              Description ItemType  RetailSales  \
# 0                      GAMLA CAB - 750ML     WINE          0.0
# 1   SANTA MARGHERITA P/GRIG ALTO - 375ML     WINE          0.0
# 2  KNOB CREEK BOURBON 9YR - 100P - 375ML   LIQUOR          0.0
# 3          J W DANT BOURBON 100P - 1.75L   LIQUOR          0.0
# 4            RAMON CORDOVA RIOJA - 750ML     WINE          0.0
#
#    RetailTransfers  WarehouseSales
# 0              1.0             0.0
# 1              1.0             0.0
# 2              8.0             0.0
# 3              2.0             0.0
# 4              4.0             0.0

# %% [markdown]
# ## 1. Create a bar chart with bars for total Retail Sales, Retail Transfers, and Warehouse Sales by Item Type.

# %%
data.groupby('ItemType').agg(sum)
# Out:
#                    Year   Month  RetailSales  RetailTransfers  WarehouseSales
# ItemType
# BEER           33132676  115830    209763.11        234924.44      2437617.32
# DUNNAGE           64552     236         0.00             0.00       -45331.00
# KEGS            7338694   27033         0.00             0.00        43558.00
# LIQUOR         57282701  197353    309847.85        334176.41        33173.32
# NON-ALCOHOL     1266826    4426      8109.97          9058.37         8656.72
# REF              102879     385       281.34           171.92        -6754.00
# STR_SUPPLIES     213823     774       995.98          3594.70            0.00
# WINE          159514312  562617    313400.42        340710.51       433009.47

# %%
dt = data[['ItemType','RetailSales','RetailTransfers','WarehouseSales']].groupby('ItemType').agg(sum)
dt.plot.bar(figsize=(14,8))

# %% [markdown]
# ## 2. Create a horizontal bar chart showing sales mix for the top 10 suppliers with the most total sales.

# %%
supp_10 = data[['Supplier','RetailSales']].groupby('Supplier').agg(sum).sort_values(by='RetailSales',ascending=False).head(10)
supp_10.plot.barh(figsize=(14,7))

# %% [markdown]
# ## 3. Create a multi-line chart that shows average Retail Sales, Retail Transfers, and Warehouse Sales per month over time.

# %%
data_mean = data[['RetailSales','RetailTransfers','WarehouseSales','Month']].groupby('Month').mean()
data.sort_values(by=['Month','RetailSales','RetailTransfers','WarehouseSales'],inplace=True)
data

# %%
data.plot(x='Month',y=['RetailSales','RetailTransfers','WarehouseSales'])

# %% [markdown]
# ## 4. Plot the same information as above but as a bar chart.

# %%
data_mean.plot.bar(figsize=(15,7))

# %% [markdown]
# ## 5. Create a multi-line chart that shows Retail Sales summed by Item Type over time (Year & Month).
#
# *Hint: There should be a line representing each Item Type.*

# %%
data_sum = data[['RetailSales','ItemType','Year','Month']].groupby(['ItemType','Year','Month']).agg(sum)
#data_sum.plot(x='Year',y=['ItemType']);
data_sum
# Out:
#                      RetailSales
# ItemType Year Month
# BEER     2017 4             0.00
#               5         25023.24
#               6         27863.26
#               8         23030.13
#               9         23852.76
# ...                          ...
# WINE     2017 10        33108.76
#               11        38275.92
#               12        51492.76
#          2018 1         29792.72
#               2         29409.39
#
# [73 rows x 1 columns]

# %%
pivot_rs = data.pivot_table(values='RetailSales', columns='ItemType', index=['Year', 'Month'], aggfunc='sum')
pivot_rs.plot(figsize=(14,8))

# %% [markdown]
# ## 6. Plot the same information as above but as a bar chart.

# %%
dtt = data.pivot_table(values='RetailSales', columns='ItemType', index=['Year', 'Month'], aggfunc='sum')
dtt.plot.bar(rot=90,figsize=(16,8))

# %%
data.pivot(index='Year',columns='ItemType', values='RetailSales').plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-0c5a7ae40534> in <module>
# ----> 1 data.pivot(index='Year',columns='ItemType', values='RetailSales').plot(kind='bar')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in pivot(self, index, columns, values)
#    5921         from pandas.core.reshape.pivot import pivot
#    5922
# -> 5923         return pivot(self, index=index, columns=columns, values=values)
#    5924
#    5925     _shared_docs[
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot(data, index, columns, values)
#     446         else:
#     447             indexed = data._constructor_sliced(data[values].values, index=index)
# --> 448     return indexed.unstack(columns)
#     449
#     450
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in unstack(self, level, fill_value)
# ...

# %% [markdown]
# ## 7. Create a scatter plot showing the relationship between Retail Sales (x-axis) and Retail Transfers (y-axis) with the plot points color-coded according to their Item Type.
#
# *Hint: Seaborn's lmplot is the easiest way to generate the scatter plot.*

# %%
sns.scatterplot(x=data.RetailSales,y=data.RetailTransfers,hue=data.ItemType)

# %% [markdown]
# ## 8. Create a scatter matrix using all the numeric fields in the data set with the plot points color-coded by Item Type.
#
# *Hint: Seaborn's pairplot may be your best option here.*

# %%
pd.plotting.scatter_matrix(data,figsize=(15,7))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000270082D83C8>,
# ...
#       dtype=object)
