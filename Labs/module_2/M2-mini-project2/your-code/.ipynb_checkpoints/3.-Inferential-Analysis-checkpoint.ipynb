# %% [markdown]
# # Inferential statistics
# ## Part III - Inferential Analysis
#
# We're now going to look for answers to the ongoing basketball discussions between you and your family. The main ones we want to reasearch are the following:
#
# - Your grandmother says that your sister couldn't play in a professional basketball league (not only the WNBA, but ANY professional basketball league) because she's too skinny and lacks muscle.
# - Your sister says that most female professional players fail their free throws.
# - Your brother-in-law heard on the TV that the average assists among NBA (male) and WNBA (female) players is 52 for the 2016-2017 season. He is convinced this average would be higher if we only considered the players from the WNBA.
#
# Let's investigate these claims and see if we can find proof to refute or support them.
#
# ### Libraries
# Import the necessary libraries first.

# %%
# Libraries
import math
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
from scipy.stats import ttest_1samp
pd.set_option('max_columns', 50)

# %% [markdown]
# ### Load the dataset
#
# Load the cleaned dataset.

# %%
wnba=pd.read_csv('../data/wnba_clean.csv')
wnba.head()
# Out:
#    Unnamed: 0             Name Team  Pos  Height  Weight        BMI  \
# 0           0    Aerial Powers  DAL    F     183    71.0  21.200991
# 1           1      Alana Beard   LA  G/F     185    73.0  21.329438
# 2           2     Alex Bentley  CON    G     170    69.0  23.875433
# 3           3  Alex Montgomery  SAN  G/F     185    84.0  24.543462
# 4           4     Alexis Jones  MIN    G     175    78.0  25.469388
#
#   Birth_Place          Birthdate  Age         College Experience  \
# 0          US   January 17, 1994   23  Michigan State          2
# 1          US       May 14, 1982   35            Duke         12
# 2          US   October 27, 1990   26      Penn State          4
# 3          US  December 11, 1988   28    Georgia Tech          6
# 4          US     August 5, 1994   23          Baylor          R
#
#    Games Played  MIN  FGM  FGA   FG%  3PM  3PA   3P%  FTM  FTA   FT%  OREB  \
# 0             8  173   30   85  35.3   12   32  37.5   21   26  80.8     6
# ...

# %% [markdown]
# # Question 1: Can my sister play in a professional female basketball league?
#
# As we said, you grandmother is convinced that your sister couldn't play in a professional league because of her physique and weight (her weight is 67kg).
#
# To find an actual answer to the question we first need to know what's the average weight of a professional female basketball player. The data we have only refers to the WNBA league and not to every female professional basketball league in the world, therefore we have no way of actually calculating it.
#
# Still, given that we do have *some* data we can **infer** it using a sample of players like the one we have.
#
# **How would you do it? Try and think about the requirements that your sample must satisfy in order to be used to infer the average weight. Do you feel it actually fulfills those requirements? Do you need to make any assumptions? We could calculate a confidence interval to do the inference, but do you know any other ways?**

# %%
'''The sample should be randomly selected, to be able to infer the average weight. Our sample, does not fulfill these requirement because, it's related to WNBA league only. If we want exploit this dataset, we can assume, that there's only one female professional league in the world WNBA.'''
# Out:
# "The sample should be randomly selected, to be able to infer the average weight. Our sample, does not fulfill these requirement because, it's related to WNBA league only. If we want exploit this dataset, we can assume, that there's only one female professional league in the world WNBA."

# %% [markdown]
# **Now that all the requirements have been taken into account, compute the confidence interval of the average weight with a confidence level of 95%.**

# %%
import scipy.stats as st

# %%
weight_mean = wnba.Weight.mean()
weight_mean
# Out:
# 78.97887323943662

# %%
weight_std = wnba.Weight.std()
weight_std
# Out:
# 10.996110408297898

# %%
sample_size = wnba.Weight.shape[0]
sample_size
# Out:
# 142

# %%
se = weight_std/sample_size**0.5
se
# Out:
# 0.9227730868415791

# %%
conf_interval=st.t.interval(0.95,df=141,loc=weight_mean,scale=se)
conf_interval
# Out:
# (77.15461406720749, 80.80313241166576)

# %% [markdown]
# **What can you say about these results?**

# %%
"For this sample, representing the WNBA league, the confidence interval of the weight is between 77.17 and 80.78"
# Out:
# 'For this sample, representing the WNBA league, the confidence interval of the weight is between 77.17 and 80.78'

# %% [markdown]
# **If your sister weighs 67kg what would you tell your grandmother in regards to her assumption?**

# %%
'I would tell her, that she would be right in her opinion'
# Out:
# 'I would tell her, that she would be right in her opinion'

# %% [markdown]
# ## Bonus: Can you plot the probability distribution of the average weight, indicating where the critical region is?

# %%
plt.hist(wnba.Weight)
# Out:
# (array([ 5., 21., 10., 33., 22., 33., 10.,  3.,  2.,  3.]),
#  array([ 55. ,  60.8,  66.6,  72.4,  78.2,  84. ,  89.8,  95.6, 101.4,
#         107.2, 113. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# # Question 2: Do female professional basketball players fail the majority of their free throws?
#
# You do not agree with your sister when she says that most female players fail their free throws. You decide to try and estimate the percentage of players that fail more than 40% of their free throws using, you guessed it, the WNBA sample.
#
# **How would you do it? Try and think about the requirements that your sample must satisfy in order to be used to infer the proportion of players that miss more than 40% of their free throws. Do you feel it actually fulfills those requirements? Do you need to make any assumptions?**

# %%
'''Same interpretation as the weight, i would say that this sample is not representative and randomly chosed.It's limited to only one professionnal femal league. So, my assumption is that there is only one femal league in basketball.'''
# Out:
# "Same interpretation as the weight, i would say that this sample is not representative and randomly chosed.It's limited to only one professionnal femal league. So, my assumption is that there is only one femal league in basketball."

# %% [markdown]
# **Now that all the requirements have been taken into account, compute the confidence interval of the proportion with a confidence level of 95%:**

# %%
# ft_mean = (wnba['FT%']/100).mean()
# ft_std = (wnba['FT%']/100).std()
# ft_size = wnba['FT%'].shape[0]
# failed more than 40%
fail_40 = wnba[wnba['FT%']<60]
size = wnba.shape[0]
p = fail_40.shape[0]/size
p
# Out:
# 0.09859154929577464

# %%
se = (p*(1-p)/size)**0.5
se
# Out:
# 0.025017072438697795

# %%
# confidence interval of having the proportion of more than 40% fail in free throw
confidence_interval = st.t.interval(0.95,df=size-1,loc=p,scale=se)
confidence_interval
# Out:
# (0.04913451103859987, 0.14804858755294942)

# %% [markdown]
# **What can you comment about our result? What would you tell your sister?**

# %%
'I would tell my sister that between only 4% and 14% of weman miss more than 40% of their free throws. which is a low proportion'
# Out:
# 'I would tell my sister that between only 4% and 14% of weman miss more than 40% of their free throws. which is a low proportion'

# %% [markdown]
# # Bonus: Can you plot the probability distribution of the proportion of missed free throws, indicating where the critical region is?

# %%
import seaborn as sns
size = wnba.shape[0]
for i,j in wnba.groupby('College'):
    prop_missed = 100-j['FT%']
    plt.hist(prop_missed)
    plt.title(i)
    plt.show()

# %% [markdown]
# # Question 3: Is the average number of assists for WNBA players only higher than the average for WNBA and NBA players together?

# %% [markdown]
# Your brother-in-law is convinced that the average assists for female professional players is higher than the average of both female and male players combined (which is 52 for the 2016-2017 season). You would like to actually prove if this is true or not but you remember your stats teacher saying "you can't *prove* anything, you just can say that *you are not* saying foolishness".
#
# **How would you do it? Try and think about the requirements that your sample must satisfy in order to do that. Do you feel it actually fulfills those requirements? Do you need to make any assumptions?**

# %%
'To be able to answer him, ideally, i should have some data from the male league nba. '

# %% [markdown]
# **Use a two-tailed one-sample t-test to see if we can reject (or not) the null hypothesis with a 95% confidence level.**

# %%
# H0: average assists for female professional players is higher than the average of both female and male players combined 
#(which is 52 for the 2016-2017 season) 
# H0 : avg > 52
# my sample is wnba data
from scipy.stats import ttest_1samp
ttest_1samp(wnba['AST'],52)
# Out:
# Ttest_1sampResult(statistic=-2.1499947192482898, pvalue=0.033261541354107166)

# %%
'''pvalue=0.03<0.05 so we can reject the null hypothesis'''
# Out:
# 'pvalue=0.03<0.05 so we can reject the null hypothesis'

# %% [markdown]
# **Now use a one-tailed one-sample t-test to see if we can reject (or not) the null hypothesis with a 95% confidence level.**

# %%
"For the one tailed one sample hypothesis, we compare pvalue to 0.025. Here pvalue>0.025 so we can confirm the null hypothesis"

# %% [markdown]
# # Bonus: Can you plot the resulting t-distribution of both tests? Indicate where the is the critical region and where does your statistic fall.**

# %%
#your code here

# %% [markdown]
# # Bonus: Satisfying your curiosity
#
# You finally managed to solve your family's debates over basketball! While you were doing that you started to take an interest in the normal distribution.
#
# You read that the normal distribution is present in a lot of natural phenomenons, like blood pressure, IQ, weight and height. If, for example, we could plot the distribution of the weights of every human on the planet right now it would have the shape of a normal distribution.
#
# In light of this you would like to see if it's possible to check if the distribution of the weights of the WNBA players is a sample distribution that comes from a population that has a normal distribution, because theoretically this should be the case.
#
# **How would you try to demonstrate that our sample fits a normal distribution? What kind of test would you use? Would you have to make any assumptions?**

# %%
#your-answer-here

# %%
# your code here

# %% [markdown]
# **What are your comments in regards to the results of the test?**

# %%
#your-answer-here
