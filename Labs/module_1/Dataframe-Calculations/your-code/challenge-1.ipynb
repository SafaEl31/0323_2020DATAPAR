# %% [markdown]
# # Challenge 1
#
# In this challenge you will be working on **Pokemon**. You will answer a series of questions in order to practice dataframe calculation, aggregation, and transformation.
#
# ![Pokemon](../images/pokemon.jpg)
#
# Follow the instructions below and enter your code.
#
# #### Import all required libraries.

# %%
# import libraries
import pandas as pd
import numpy as np

# %% [markdown]
# #### Import data set.
#
# Import data set `Pokemon` from Ironhack's database. Read the data into a dataframe called `pokemon`.
#
# *Data set attributed to [Alberto Barradas](https://www.kaggle.com/abcsds/pokemon/)*

# %%
# import data set from Ironhack's database
pokemon = pd.read_csv('../data-set/Pokemon.csv')

# %% [markdown]
# #### Print first 10 rows of `pokemon`.

# %%
pokemon.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False
# 9       50       64     43           1      False

# %% [markdown]
# When you look at a data set, you often wonder what each column means. Some open-source data sets provide descriptions of the data set. In many cases, data descriptions are extremely useful for data analysts to perform work efficiently and successfully.
#
# For the `Pokemon.csv` data set, fortunately, the owner provided descriptions which you can see [here](https://www.kaggle.com/abcsds/pokemon/home). For your convenience, we are including the descriptions below. Read the descriptions and understand what each column means. This knowledge is helpful in your work with the data.
#
# | Column | Description |
# | --- | --- |
# | # | ID for each pokemon |
# | Name | Name of each pokemon |
# | Type 1 | Each pokemon has a type, this determines weakness/resistance to attacks |
# | Type 2 | Some pokemon are dual type and have 2 |
# | Total | A general guide to how strong a pokemon is |
# | HP | Hit points, or health, defines how much damage a pokemon can withstand before fainting |
# | Attack | The base modifier for normal attacks (eg. Scratch, Punch) |
# | Defense | The base damage resistance against normal attacks |
# | SP Atk | Special attack, the base modifier for special attacks (e.g. fire blast, bubble beam) |
# | SP Def | The base damage resistance against special attacks |
# | Speed | Determines which pokemon attacks first each round |
# | Generation | Number of generation |
# | Legendary | True if Legendary Pokemon False if not |

# %% [markdown]
# #### Obtain the distinct values across `Type 1` and `Type 2`.
#
# Exctract all the values in `Type 1` and `Type 2`. Then create an array containing the distinct values across both fields.

# %%
pokemon['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
pokemon['Type 2'].unique()
# Out:
# array(['Poison', nan, 'Flying', 'Dragon', 'Ground', 'Fairy', 'Grass',
#        'Fighting', 'Psychic', 'Steel', 'Ice', 'Rock', 'Dark', 'Water',
#        'Electric', 'Fire', 'Ghost', 'Bug', 'Normal'], dtype=object)

# %%
set(pokemon['Type 1'].to_list()+pokemon['Type 2'].to_list())
# Out:
# {'Bug',
#  'Dark',
#  'Dragon',
#  'Electric',
#  'Fairy',
#  'Fighting',
#  'Fire',
#  'Flying',
#  'Ghost',
#  'Grass',
#  'Ground',
#  'Ice',
#  'Normal',
#  'Poison',
#  'Psychic',
#  'Rock',
#  'Steel',
#  'Water'}

# %%
# ravel flaten matrix (list of list) into a list
set(pokemon['Type 1'])

# %%
pokemon[['Type 1','Type 2']].apply(lambda x:tuple(set((x['Type 1'],x['Type 2']))),axis=1).values
# Out:
# array([('Dragon', 'Fire'), ('Dragon', 'Electric'), ('Rock', 'Fire'),
#        ('Flying', 'Steel'), ('Psychic', 'Grass'), ('Dragon', 'Grass'),
#        ('Bug', 'Water'), ('Bug', 'Ghost'), ('Fairy', 'Dragon'),
#        ('Fire', 'Ground'), ('Ground', 'Grass'), ('Water', 'Steel'),
#        ('Water', 'Normal'), ('Ghost', 'Dark'), ('Bug', 'Poison'),
#        ('Ghost', 'Ice'), ('Ghost', 'Electric'), ('Electric', 'Fire'),
#        ('Water', 'Electric'), ('Electric', 'Ice'), ('Electric', 'Grass'),
#        ('Dragon', 'Steel'), ('Fire', 'Steel'), ('Psychic', 'Fire'),
#        ('Steel', 'Ground'), ('Electric', 'Ground'), ('Fighting', 'Steel'),
#        ('Rock', 'Fighting'), ('Dragon', 'Fire'), ('Dragon', 'Electric'),
#        ('Normal', 'Ground'), ('Dark', 'Fighting'), ('Water', 'Poison'),
#        ('Dragon', 'Poison'), ('Flying', 'Fighting'),
#        ('Fairy', 'Electric'), ('Ghost', 'Psychic'), ('Psychic', 'Dark'),
#        ('Water', 'Fire')], dtype=object)

# %%
pokemon[['Type 1','Type 2']].apply(lambda x: ()&())

# %%
#pokemon['Type 1'].duplicated().sum()
pokemon['Type 2'].duplicated().sum()
# Out:
# 781

# %%
pokemon.drop_duplicates(subset =['Type 1','Type 2'], keep = False, inplace = True)

# %%
pokemon;

# %% [markdown]
# #### Cleanup `Name` that contain "Mega".
#
# If you have checked out the pokemon names carefully enough, you should have found there are junk texts in the pokemon names which contain "Mega". We want to clean up the pokemon names. For instance, "VenusaurMega Venusaur" should be "Mega Venusaur", and "CharizardMega Charizard X" should be "Mega Charizard X".

# %%
pokemon;

# %%
# # your code here
# def func(x):
#     return 'Mega '+x.split('Mega')[1]

# #pokemon.loc[pokemon.Name.str.contains('Mega')]['Name'].apply(func);

# pokemon['Name'] = pokemon.loc[pokemon.Name.str.contains('Mega'), 'Name'].apply(func)
# # test transformed data
# #pokemon.head(10)

# %%
pokemon.Name=pokemon.Name.map(lambda x: 'Mega '+x.split('Mega')[-1] if 'Mega' in x else x)

# %%
# or
pokemon.Name.str.split('Mega').apply(lambda x: 'Mega '+x[-1] if len(x)>1 else x[-1])
# Out:
# 7         Mega   Charizard X
# 196          Mega   Ampharos
# 237                 Magcargo
# 245                 Skarmory
# 271                   Celebi
# 275          Mega   Sceptile
# 307                  Surskit
# 316                 Shedinja
# 366           Mega   Altaria
# 424    GroudonPrimal Groudon
# 434                 Torterra
# 440                 Empoleon
# 445                  Bibarel
# 490                Spiritomb
# 501                  Skorupi
# 530                 Froslass
# 531                    Rotom
# 532          RotomHeat Rotom
# 533          RotomWash Rotom
# 534         RotomFrost Rotom
# 536           RotomMow Rotom
# 540                   Dialga
# 542                  Heatran
# 553                  Victini
# 589                Excadrill
# 679                 Stunfisk
# 699                 Cobalion
# 700                Terrakion
# 706                 Reshiram
# 707                   Zekrom
# 728                Diggersby
# 743                  Pangoro
# 760                   Skrelp
# 761                 Dragalge
# 771                 Hawlucha
# 772                  Dedenne
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, dtype: object

# %%
pokemon
# Out:
#        #                   Name    Type 1    Type 2  Total   HP  Attack  \
# 7      6      Mega  Charizard X      Fire    Dragon    634   78     130
# 196  181         Mega  Ampharos  Electric    Dragon    610   90      95
# 237  219               Magcargo      Fire      Rock    410   50      50
# 245  227               Skarmory     Steel    Flying    465   65      80
# 271  251                 Celebi   Psychic     Grass    600  100     100
# 275  254         Mega  Sceptile     Grass    Dragon    630   70     110
# 307  283                Surskit       Bug     Water    269   40      30
# 316  292               Shedinja       Bug     Ghost    236    1      90
# 366  334          Mega  Altaria    Dragon     Fairy    590   75     110
# 424  383  GroudonPrimal Groudon    Ground      Fire    770  100     180
# 434  389               Torterra     Grass    Ground    525   95     109
# 440  395               Empoleon     Water     Steel    530   84      86
# 445  400                Bibarel    Normal     Water    410   79      85
# 490  442              Spiritomb     Ghost      Dark    485   50      92
# 501  451                Skorupi    Poison       Bug    330   40      50
# 530  478               Froslass       Ice     Ghost    480   70      80
# 531  479                  Rotom  Electric     Ghost    440   50      50
# 532  479        RotomHeat Rotom  Electric      Fire    520   50      65
# 533  479        RotomWash Rotom  Electric     Water    520   50      65
# 534  479       RotomFrost Rotom  Electric       Ice    520   50      65
# 536  479         RotomMow Rotom  Electric     Grass    520   50      65
# 540  483                 Dialga     Steel    Dragon    680  100     120
# 542  485                Heatran      Fire     Steel    600   91      90
# 553  494                Victini   Psychic      Fire    600  100     100
# 589  530              Excadrill    Ground     Steel    508  110     135
# 679  618               Stunfisk    Ground  Electric    471  109      66
# 699  638               Cobalion     Steel  Fighting    580   91      90
# 700  639              Terrakion      Rock  Fighting    580   91     129
# 706  643               Reshiram    Dragon      Fire    680  100     120
# 707  644                 Zekrom    Dragon  Electric    680  100     150
# 728  660              Diggersby    Normal    Ground    423   85      56
# 743  675                Pangoro  Fighting      Dark    495   95     124
# 760  690                 Skrelp    Poison     Water    320   50      60
# 761  691               Dragalge    Poison    Dragon    494   65      75
# 771  701               Hawlucha  Fighting    Flying    500   78      92
# 772  702                Dedenne  Electric     Fairy    431   67      58
# 797  720    HoopaHoopa Confined   Psychic     Ghost    600   80     110
# 798  720     HoopaHoopa Unbound   Psychic      Dark    680   80     160
# 799  721              Volcanion      Fire     Water    600   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 7        111      130       85    100           1      False
# 196      105      165      110     45           2      False
# 237      120       80       80     30           2      False
# 245      140       40       70     70           2      False
# 271      100      100      100    100           2      False
# 275       75      145       85    145           3      False
# 307       32       50       52     65           3      False
# 316       45       30       30     40           3      False
# 366      110      110      105     80           3      False
# 424      160      150       90     90           3       True
# 434      105       75       85     56           4      False
# 440       88      111      101     60           4      False
# 445       60       55       60     71           4      False
# 490      108       92      108     35           4      False
# 501       90       30       55     65           4      False
# 530       70       80       70    110           4      False
# 531       77       95       77     91           4      False
# 532      107      105      107     86           4      False
# 533      107      105      107     86           4      False
# 534      107      105      107     86           4      False
# 536      107      105      107     86           4      False
# 540      120      150      100     90           4       True
# 542      106      130      106     77           4       True
# 553      100      100      100    100           5       True
# 589       60       50       65     88           5      False
# 679       84       81       99     32           5      False
# 699      129       90       72    108           5       True
# 700       90       72       90    108           5       True
# 706      100      150      120     90           5       True
# 707      120      120      100     90           5       True
# 728       77       50       77     78           6      False
# 743       78       69       71     58           6      False
# 760       60       60       60     30           6      False
# 761       90       97      123     44           6      False
# 771       75       74       63    118           6      False
# 772       57       81       67    101           6      False
# 797       60      150      130     70           6       True
# 798       60      170      130     80           6       True
# 799      120      130       90     70           6       True

# %% [markdown]
# #### Create a new column called `A/D Ratio` whose value equals to `Attack` devided by `Defense`.
#
# For instance, if a pokemon has the Attack score 49 and Defense score 49, the corresponding `A/D Ratio` is 49/49=1.

# %%
pokemon['A/D Ratio']=pokemon['Attack']/pokemon['Defense']
pokemon
# Out:
#        #                   Name    Type 1    Type 2  Total   HP  Attack  \
# 7      6      Mega  Charizard X      Fire    Dragon    634   78     130
# 196  181         Mega  Ampharos  Electric    Dragon    610   90      95
# 237  219               Magcargo      Fire      Rock    410   50      50
# 245  227               Skarmory     Steel    Flying    465   65      80
# 271  251                 Celebi   Psychic     Grass    600  100     100
# 275  254         Mega  Sceptile     Grass    Dragon    630   70     110
# 307  283                Surskit       Bug     Water    269   40      30
# 316  292               Shedinja       Bug     Ghost    236    1      90
# 366  334          Mega  Altaria    Dragon     Fairy    590   75     110
# 424  383  GroudonPrimal Groudon    Ground      Fire    770  100     180
# 434  389               Torterra     Grass    Ground    525   95     109
# 440  395               Empoleon     Water     Steel    530   84      86
# 445  400                Bibarel    Normal     Water    410   79      85
# 490  442              Spiritomb     Ghost      Dark    485   50      92
# 501  451                Skorupi    Poison       Bug    330   40      50
# 530  478               Froslass       Ice     Ghost    480   70      80
# 531  479                  Rotom  Electric     Ghost    440   50      50
# 532  479        RotomHeat Rotom  Electric      Fire    520   50      65
# 533  479        RotomWash Rotom  Electric     Water    520   50      65
# 534  479       RotomFrost Rotom  Electric       Ice    520   50      65
# 536  479         RotomMow Rotom  Electric     Grass    520   50      65
# 540  483                 Dialga     Steel    Dragon    680  100     120
# 542  485                Heatran      Fire     Steel    600   91      90
# 553  494                Victini   Psychic      Fire    600  100     100
# 589  530              Excadrill    Ground     Steel    508  110     135
# 679  618               Stunfisk    Ground  Electric    471  109      66
# 699  638               Cobalion     Steel  Fighting    580   91      90
# 700  639              Terrakion      Rock  Fighting    580   91     129
# 706  643               Reshiram    Dragon      Fire    680  100     120
# 707  644                 Zekrom    Dragon  Electric    680  100     150
# 728  660              Diggersby    Normal    Ground    423   85      56
# 743  675                Pangoro  Fighting      Dark    495   95     124
# 760  690                 Skrelp    Poison     Water    320   50      60
# 761  691               Dragalge    Poison    Dragon    494   65      75
# 771  701               Hawlucha  Fighting    Flying    500   78      92
# 772  702                Dedenne  Electric     Fairy    431   67      58
# 797  720    HoopaHoopa Confined   Psychic     Ghost    600   80     110
# 798  720     HoopaHoopa Unbound   Psychic      Dark    680   80     160
# 799  721              Volcanion      Fire     Water    600   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio
# 7        111      130       85    100           1      False   1.171171
# 196      105      165      110     45           2      False   0.904762
# 237      120       80       80     30           2      False   0.416667
# 245      140       40       70     70           2      False   0.571429
# 271      100      100      100    100           2      False   1.000000
# 275       75      145       85    145           3      False   1.466667
# 307       32       50       52     65           3      False   0.937500
# 316       45       30       30     40           3      False   2.000000
# 366      110      110      105     80           3      False   1.000000
# 424      160      150       90     90           3       True   1.125000
# 434      105       75       85     56           4      False   1.038095
# 440       88      111      101     60           4      False   0.977273
# 445       60       55       60     71           4      False   1.416667
# 490      108       92      108     35           4      False   0.851852
# 501       90       30       55     65           4      False   0.555556
# 530       70       80       70    110           4      False   1.142857
# 531       77       95       77     91           4      False   0.649351
# 532      107      105      107     86           4      False   0.607477
# 533      107      105      107     86           4      False   0.607477
# 534      107      105      107     86           4      False   0.607477
# 536      107      105      107     86           4      False   0.607477
# 540      120      150      100     90           4       True   1.000000
# 542      106      130      106     77           4       True   0.849057
# 553      100      100      100    100           5       True   1.000000
# 589       60       50       65     88           5      False   2.250000
# 679       84       81       99     32           5      False   0.785714
# 699      129       90       72    108           5       True   0.697674
# 700       90       72       90    108           5       True   1.433333
# 706      100      150      120     90           5       True   1.200000
# 707      120      120      100     90           5       True   1.250000
# 728       77       50       77     78           6      False   0.727273
# 743       78       69       71     58           6      False   1.589744
# 760       60       60       60     30           6      False   1.000000
# 761       90       97      123     44           6      False   0.833333
# 771       75       74       63    118           6      False   1.226667
# 772       57       81       67    101           6      False   1.017544
# 797       60      150      130     70           6       True   1.833333
# 798       60      170      130     80           6       True   2.666667
# 799      120      130       90     70           6       True   0.916667

# %% [markdown]
# #### Identify the pokemon with the highest `A/D Ratio`.

# %%
pokemon.loc[pokemon['A/D Ratio'].idxmax()]
# Out:
# #                            720
# Name          HoopaHoopa Unbound
# Type 1                   Psychic
# Type 2                      Dark
# Total                        680
# HP                            80
# Attack                       160
# Defense                       60
# Sp. Atk                      170
# Sp. Def                      130
# Speed                         80
# Generation                     6
# Legendary                   True
# A/D Ratio                2.66667
# Name: 798, dtype: object

# %% [markdown]
# #### Identify the pokemon with the lowest A/D Ratio.

# %%
pokemon.loc[pokemon['A/D Ratio'].idxmin()]
# Out:
# #                  219
# Name          Magcargo
# Type 1            Fire
# Type 2            Rock
# Total              410
# HP                  50
# Attack              50
# Defense            120
# Sp. Atk             80
# Sp. Def             80
# Speed               30
# Generation           2
# Legendary        False
# A/D Ratio     0.416667
# Name: 237, dtype: object

# %% [markdown]
# #### Create a new column called `Combo Type` whose value combines `Type 1` and `Type 2`.
#
# Rules:
#
# * If both `Type 1` and `Type 2` have valid values, the `Combo Type` value should contain both values in the form of `<Type 1> <Type 2>`. For example, if `Type 1` value is `Grass` and `Type 2` value is `Poison`, `Combo Type` will be `Grass-Poison`.
#
# * If `Type 1` has valid value but `Type 2` is not, `Combo Type` will be the same as `Type 1`. For example, if `Type 1` is `Fire` whereas `Type 2` is `NaN`, `Combo Type` will be `Fire`.

# %%
#np.NaN
def set_combo_type(x,y):
    if x is np.nan:
        return y
    
    elif y is np.nan:
        return x
    else:
        return x +'-'+y

pokemon['Combo Type'] = pokemon.apply(lambda x: set_combo_type(x['Type 1'],x['Type 2']),axis=1)
pokemon.head(5)
# Out:
#        #               Name    Type 1  Type 2  Total   HP  Attack  Defense  \
# 7      6  Mega  Charizard X      Fire  Dragon    634   78     130      111
# 196  181     Mega  Ampharos  Electric  Dragon    610   90      95      105
# 237  219           Magcargo      Fire    Rock    410   50      50      120
# 245  227           Skarmory     Steel  Flying    465   65      80      140
# 271  251             Celebi   Psychic   Grass    600  100     100      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio  \
# 7        130       85    100           1      False   1.171171
# 196      165      110     45           2      False   0.904762
# 237       80       80     30           2      False   0.416667
# 245       40       70     70           2      False   0.571429
# 271      100      100    100           2      False   1.000000
#
#           Combo Type
# 7        Fire-Dragon
# 196  Electric-Dragon
# 237        Fire-Rock
# 245     Steel-Flying
# 271    Psychic-Grass

# %% [markdown]
# #### Identify the pokemon whose `A/D Ratio` are among the top 5.

# %%
## top_pok = pokemon.sort_values('A/D Ratio',ascending=False).head(5)
## other solution to get top 5
pokemon.nlargest(5, ['A/D Ratio'])
# Out:
#        #                 Name    Type 1 Type 2  Total   HP  Attack  Defense  \
# 798  720   HoopaHoopa Unbound   Psychic   Dark    680   80     160       60
# 589  530            Excadrill    Ground  Steel    508  110     135       60
# 316  292             Shedinja       Bug  Ghost    236    1      90       45
# 797  720  HoopaHoopa Confined   Psychic  Ghost    600   80     110       60
# 743  675              Pangoro  Fighting   Dark    495   95     124       78
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio     Combo Type
# 798      170      130     80           6       True   2.666667   Psychic-Dark
# 589       50       65     88           5      False   2.250000   Ground-Steel
# 316       30       30     40           3      False   2.000000      Bug-Ghost
# 797      150      130     70           6       True   1.833333  Psychic-Ghost
# 743       69       71     58           6      False   1.589744  Fighting-Dark

# %% [markdown]
# #### For the 5 pokemon printed above, aggregate `Combo Type` and use a list to store the unique values.
#
# Your end product is a list containing the distinct `Combo Type` values of the 5 pokemon with the highest `A/D Ratio`.

# %%
list_top_type=top_pok['Combo Type'].unique()
list_top_type
# Out:
# array(['Psychic-Dark', 'Ground-Steel', 'Bug-Ghost', 'Psychic-Ghost',
#        'Fighting-Dark'], dtype=object)

# %% [markdown]
# #### For each of the `Combo Type` values obtained from the previous question, calculate the mean scores of all numeric fields across all pokemon.
#
# Your output should look like below:
#
# ![Aggregate](../images/aggregated-mean.png)

# %%
pokemon[pokemon['Combo Type'].isin(list_top_type)].groupby('Combo Type').agg('mean')
# Out:
#                  #  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Combo Type
# Bug-Ghost      292    236    1      90       45       30       30     40
# Fighting-Dark  675    495   95     124       78       69       71     58
# Ground-Steel   530    508  110     135       60       50       65     88
# Psychic-Dark   720    680   80     160       60      170      130     80
# Psychic-Ghost  720    600   80     110       60      150      130     70
#
#                Generation  Legendary  A/D Ratio
# Combo Type
# Bug-Ghost               3      False   2.000000
# Fighting-Dark           6      False   1.589744
# Ground-Steel            5      False   2.250000
# Psychic-Dark            6       True   2.666667
# Psychic-Ghost           6       True   1.833333
